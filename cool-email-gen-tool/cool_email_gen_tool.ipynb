# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    model="llama-3.1-8b-instant",
    temperature=0,
    groq_api_key='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', 
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

response = llm.invoke("The first person invented ai")
print(response)
# Out:
# content='While it\'s difficult to pinpoint a single person as the "first" inventor of AI, I can provide some insights on the early pioneers who contributed to the development of artificial intelligence.\n\nOne of the earliest pioneers in the field of AI is often credited to be:\n\n1. **Charles Babbage** (1791-1871): An English mathematician, philosopher, and inventor, Babbage is often considered the father of the computer. He designed the Analytical Engine, a mechanical computer that could perform calculations and execute programs, laying the foundation for modern computer science and AI.\n\nAnother key figure is:\n\n2. **Alan Turing** (1912-1954): A British mathematician, computer scientist, and logician, Turing is widely considered the father of computer science and AI. He proposed the Turing Test, a measure of a machine\'s ability to exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human. Turing\'s work on the theoretical foundations of computation 
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.careerjet.com.bd/jobad/bd19f60e971e62503aa776deb03d32ef0a")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Full Stack Web Developer in Sylhet with Software Solution Inc. | Careerjet
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Search jobs
#
#
#
#
#
#
#
#     Post your CV
#
#
#
#
#
#
#       Find companies
#
#
#
#
#
#
#
#       Post a job
#
#
#
#
#
#     Sign in
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Full Stack Web Developer
#
#
#         Software Solution Inc.
#
#
#
#
#
# Sylhet
#
#
#
#       Tk. 20,000-30,000 per month
#
#
#
#       Permanent
#
#
#
#       Full-time
#
#
#
#
# 2 days ago
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Full Stack Web Developer',
#   'experience': 'At least 1 year',
#   'skills': ['Android application development',
#    'AWS Cloud',
#    'Digital Marketing (Social Media Marketing)',
#    'Graphic Designer',
#    'iOS Application Development',
#    'Software Development',
#    'Video Editing',
#    'VPS',
#    'Web Developer/ Web Designer',
#    'Windows and Linux Operating System'],
# ...

# %%
import pandas as pd
df = pd.read_csv('my_portfolio.csv')
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import uuid
# ----> 2 import chromadb
#       4 client = chromadb.PersistentClient('vectorstore')
#       5 collection = client.get_or_create_collection(name="portfolio")
#
# ModuleNotFoundError: No module named 'chromadb'
