# %%
import pandas as pd
import numpy as np
import math
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
x = df[['Mileage','Age(yrs)']]
y = df['Sell Price($)']

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 16

# %%
x_train
# Out:
#     Mileage  Age(yrs)
# 9     67000         6
# 5     59000         5
# 12    59000         5
# 11    79000         7
# 3     22500         2
# 4     46000         4
# 10    83000         7
# 6     52000         5
# 13    58780         4
# 14    82450         7
# 2     57000         5
# 18    87600         8
# 19    52000         5
# 15    25400         3
# 17    69000         5
# 1     35000         3

# %%
model = linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.predict(x_test))
x_test
# Out:
# [22397.02155878 37289.09311452 21439.7303103  14472.34015667]
#     Mileage  Age(yrs)
# 0     69000         6
# 16    28000         2
# 7     72000         6
# 8     91000         8

# %%
y_test
# Out:
# 0     18000
# 16    35500
# 7     19300
# 8     12000
# Name: Sell Price($), dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.8903374334545744

# %%
import joblib
joblib.dump(model, 'carprice_model.joblib')
loaded_model = joblib.load('carprice_model.joblib')

# %%
loaded_model.predict(x_train)
# Out:
# array([23035.21572443, 26040.26517701, 26040.26517701, 18753.77794055,
#        39044.12707007, 30640.80004372, 17477.38960925, 28273.9447568 ,
#        26562.73932519, 17652.8930048 , 26678.45934266, 15557.27023828,
#        28273.9447568 , 37666.47273991, 22849.29434874, 34603.14074477])

# %%
y_train
# Out:
# 9     22000
# 5     26750
# 12    26000
# 11    19500
# 3     40000
# 4     31500
# 10    18700
# 6     32000
# 13    27500
# 14    19400
# 2     26100
# 18    12800
# 19    28200
# 15    35000
# 17    19700
# 1     34000
# Name: Sell Price($), dtype: int64
