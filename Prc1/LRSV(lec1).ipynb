# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("area_price.csv")
df.columns = ["area", "price"]
df
# Out:
#    area   price
# 0   600   50000
# 1   750   62000
# 2   900   75000
# 3  1100   90000
# 4  1300  105000
# 5  1500  120000
# 6  1700  135000
# 7  1900  150000
# 8  2100  165000
# 9  2300  180000

# %%
# %matplotlib inline
plt.xlabel('area(sq ft)', fontsize=20)
plt.ylabel('price (BDT)',fontsize=20)
plt.scatter(df.area,df.price,color='red',marker='+')
plt.plot(df.area, reg.predict(df[['area']]),color='green')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict(pd.DataFrame([[3300]], columns=["area"]))
# Out:
# array([256546.85074749])

# %%
reg.coef_
# Out:
# array([76.04607467])

# %%
reg.intercept_
# Out:
# 5594.804346050136

# %%
76.04607467*3300+5594.804346050136
# Out:
# 256546.85075705012

# %%
d = pd.read_csv("areas.csv")
d.head(10)
# Out:
#    area
# 0   500
# 1   750
# 2  1000
# 3  1250
# 4  1500
# 5  1750
# 6  2000
# 7  2250
# 8  2500
# 9  2750

# %%
x=reg.predict(d)

# %%
d['prices']=x

# %%
d.to_csv("prediction.csv",index=False)
